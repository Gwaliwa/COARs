# %%
#importing all the necesary packages
import io
from io import StringIO
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfpage import PDFPage
import os
import sys, getopt

# %%
#We will convert all the CPD pdfs into text documents- so that we can run text mining on it
#converts pdf, returns its text content as a string
def convert(fname, pages=None):
    if not pages:
        pagenums = set()
    else:
        pagenums = set(pages)

    output = io.StringIO()
    manager = PDFResourceManager()
    converter = TextConverter(manager, output, laparams=LAParams())
    interpreter = PDFPageInterpreter(manager, converter)

    infile = open(fname, 'rb')
    for page in PDFPage.get_pages(infile, pagenums):
        interpreter.process_page(page)
    infile.close()
    converter.close()
    text = output.getvalue()
    output.close
    return text

# %%
#converts all pdfs in directory pdfDir, saves all resulting txt files to txtdir
def convertMultiple(pdfDir, txtDir):
    if pdfDir == "": pdfDir = os.getcwd() + "\\" #if no pdfDir passed in 
    for pdf in os.listdir(pdfDir): #iterate through pdfs in pdf directory
        fileExtension = pdf.split(".")[-1]
        if fileExtension == "pdf":
            pdfFilename = pdfDir + pdf 
            print(pdfDir)
            print(pdf)
            print(pdfFilename)
            text = convert(pdfFilename) #get string of text content of pdf
            textFilename = txtDir + pdf+ ".txt"
            textFile = open(textFilename, "w", encoding="utf-8") #make text file
            textFile.write(text) #write text to text file

# %%
# set paths accordingly-(COMMENTED AFTER ONCE DONE):
pdfDir = "C:/Users/ndehingia/Desktop/AI in eval/OOS Children Tami/COARs/2018/"
txtDir = "C:/Users/ndehingia/Desktop/AI in eval/OOS Children Tami/COARs/TXTFiles/"
#uncomment this when you want to run the conversion
convertMultiple(pdfDir, txtDir)
# Out:
# C:/Users/ndehingia/Desktop/AI in eval/OOS Children Tami/COARs/2018/
# Afghanistan_2018_COAR.pdf
# C:/Users/ndehingia/Desktop/AI in eval/OOS Children Tami/COARs/2018/Afghanistan_2018_COAR.pdf
# C:/Users/ndehingia/Desktop/AI in eval/OOS Children Tami/COARs/2018/
# Albania_2018_COAR.pdf
# C:/Users/ndehingia/Desktop/AI in eval/OOS Children Tami/COARs/2018/Albania_2018_COAR.pdf
# C:/Users/ndehingia/Desktop/AI in eval/OOS Children Tami/COARs/2018/
# Algeria_2018_COAR.pdf
# C:/Users/ndehingia/Desktop/AI in eval/OOS Children Tami/COARs/2018/Algeria_2018_COAR.pdf
# C:/Users/ndehingia/Desktop/AI in eval/OOS Children Tami/COARs/2018/
# Angola_2018_COAR.pdf
# C:/Users/ndehingia/Desktop/AI in eval/OOS Children Tami/COARs/2018/Angola_2018_COAR.pdf
# C:/Users/ndehingia/Desktop/AI in eval/OOS Children Tami/COARs/2018/
# Argentina_2018_COAR.pdf
# C:/Users/ndehingia/Desktop/AI in eval/OOS Children Tami/COARs/2018/Argentina_2018_COAR.pdf
# ...

# %%
# set paths accordingly-(COMMENTED AFTER ONCE DONE):
pdfDir = "C:/Users/ndehingia/Desktop/AI in eval/OOS Children Tami/COARs/2019/"
txtDir = "C:/Users/ndehingia/Desktop/AI in eval/OOS Children Tami/COARs/TXTFiles/"
#uncomment this when you want to run the conversion
convertMultiple(pdfDir, txtDir)
# Out:
# C:/Users/ndehingia/Desktop/AI in eval/OOS Children Tami/COARs/2019/
# Afghanistan-2019-COAR.pdf
# C:/Users/ndehingia/Desktop/AI in eval/OOS Children Tami/COARs/2019/Afghanistan-2019-COAR.pdf
# C:/Users/ndehingia/Desktop/AI in eval/OOS Children Tami/COARs/2019/
# Albania-2019-COAR(1).pdf
# C:/Users/ndehingia/Desktop/AI in eval/OOS Children Tami/COARs/2019/Albania-2019-COAR(1).pdf
# C:/Users/ndehingia/Desktop/AI in eval/OOS Children Tami/COARs/2019/
# Algeria-2019-COAR.pdf
# C:/Users/ndehingia/Desktop/AI in eval/OOS Children Tami/COARs/2019/Algeria-2019-COAR.pdf
# C:/Users/ndehingia/Desktop/AI in eval/OOS Children Tami/COARs/2019/
# Angola-2019-COAR.pdf
# C:/Users/ndehingia/Desktop/AI in eval/OOS Children Tami/COARs/2019/Angola-2019-COAR.pdf
# C:/Users/ndehingia/Desktop/AI in eval/OOS Children Tami/COARs/2019/
# Argentina-2019-COAR.pdf
# C:/Users/ndehingia/Desktop/AI in eval/OOS Children Tami/COARs/2019/Argentina-2019-COAR.pdf
# ...

# %%
# set paths accordingly-(COMMENTED AFTER ONCE DONE):
pdfDir = "C:/Users/ndehingia/Desktop/AI in eval/OOS Children Tami/COARs/2020/"
txtDir = "C:/Users/ndehingia/Desktop/AI in eval/OOS Children Tami/COARs/TXTFiles/"
#uncomment this when you want to run the conversion
convertMultiple(pdfDir, txtDir)
# Out:
# C:/Users/ndehingia/Desktop/AI in eval/OOS Children Tami/COARs/2020/
# Afghanistan-2020-COAR.pdf.pdf
# C:/Users/ndehingia/Desktop/AI in eval/OOS Children Tami/COARs/2020/Afghanistan-2020-COAR.pdf.pdf
# C:/Users/ndehingia/Desktop/AI in eval/OOS Children Tami/COARs/2020/
# Albania-2020-COAR.pdf
# C:/Users/ndehingia/Desktop/AI in eval/OOS Children Tami/COARs/2020/Albania-2020-COAR.pdf
# C:/Users/ndehingia/Desktop/AI in eval/OOS Children Tami/COARs/2020/
# Algeria-2020-COAR.pdf
# C:/Users/ndehingia/Desktop/AI in eval/OOS Children Tami/COARs/2020/Algeria-2020-COAR.pdf
# C:/Users/ndehingia/Desktop/AI in eval/OOS Children Tami/COARs/2020/
# Angola-2020-COAR.pdf
# C:/Users/ndehingia/Desktop/AI in eval/OOS Children Tami/COARs/2020/Angola-2020-COAR.pdf
# C:/Users/ndehingia/Desktop/AI in eval/OOS Children Tami/COARs/2020/
# Argentina-2020-COAR.pdf
# C:/Users/ndehingia/Desktop/AI in eval/OOS Children Tami/COARs/2020/Argentina-2020-COAR.pdf
# ...

# %%
# set paths accordingly-(COMMENTED AFTER ONCE DONE):
pdfDir = "C:/Users/ndehingia/Desktop/AI in eval/OOS Children Tami/COARs/2021/"
txtDir = "C:/Users/ndehingia/Desktop/AI in eval/OOS Children Tami/COARs/TXTFiles/"
#uncomment this when you want to run the conversion
convertMultiple(pdfDir, txtDir)
# Out:
# C:/Users/ndehingia/Desktop/AI in eval/OOS Children Tami/COARs/2021/
# Afghanistan-2021-COAR.pdf
# C:/Users/ndehingia/Desktop/AI in eval/OOS Children Tami/COARs/2021/Afghanistan-2021-COAR.pdf
# C:/Users/ndehingia/Desktop/AI in eval/OOS Children Tami/COARs/2021/
# Albania-2021-COAR.pdf
# C:/Users/ndehingia/Desktop/AI in eval/OOS Children Tami/COARs/2021/Albania-2021-COAR.pdf
# C:/Users/ndehingia/Desktop/AI in eval/OOS Children Tami/COARs/2021/
# Algeria-2021-COAR.pdf
# C:/Users/ndehingia/Desktop/AI in eval/OOS Children Tami/COARs/2021/Algeria-2021-COAR.pdf
# C:/Users/ndehingia/Desktop/AI in eval/OOS Children Tami/COARs/2021/
# Angola-2021-COAR.pdf
# C:/Users/ndehingia/Desktop/AI in eval/OOS Children Tami/COARs/2021/Angola-2021-COAR.pdf
# C:/Users/ndehingia/Desktop/AI in eval/OOS Children Tami/COARs/2021/
# Argentina-2021-COAR.pdf
# C:/Users/ndehingia/Desktop/AI in eval/OOS Children Tami/COARs/2021/Argentina-2021-COAR.pdf
# ...

# %%
# set paths accordingly-(COMMENTED AFTER ONCE DONE):
pdfDir = "C:/Users/ndehingia/Desktop/AI in eval/OOS Children Tami/COARs/2022/"
txtDir = "C:/Users/ndehingia/Desktop/AI in eval/OOS Children Tami/COARs/TXTFiles/"
#uncomment this when you want to run the conversion
convertMultiple(pdfDir, txtDir)
# Out:
# C:/Users/ndehingia/Desktop/AI in eval/OOS Children Tami/COARs/2022/
# Afghanistan-2022-COAR.pdf
# C:/Users/ndehingia/Desktop/AI in eval/OOS Children Tami/COARs/2022/Afghanistan-2022-COAR.pdf
# C:/Users/ndehingia/Desktop/AI in eval/OOS Children Tami/COARs/2022/
# Albania-2022-COAR.pdf
# C:/Users/ndehingia/Desktop/AI in eval/OOS Children Tami/COARs/2022/Albania-2022-COAR.pdf
# C:/Users/ndehingia/Desktop/AI in eval/OOS Children Tami/COARs/2022/
# Algeria-2022-COAR.pdf
# C:/Users/ndehingia/Desktop/AI in eval/OOS Children Tami/COARs/2022/Algeria-2022-COAR.pdf
# C:/Users/ndehingia/Desktop/AI in eval/OOS Children Tami/COARs/2022/
# Angola-2022-COAR.pdf
# C:/Users/ndehingia/Desktop/AI in eval/OOS Children Tami/COARs/2022/Angola-2022-COAR.pdf
# C:/Users/ndehingia/Desktop/AI in eval/OOS Children Tami/COARs/2022/
# Argentina-2022-COAR.pdf
# C:/Users/ndehingia/Desktop/AI in eval/OOS Children Tami/COARs/2022/Argentina-2022-COAR.pdf
# ...

# %%
# Loop through all TEXT files in a folder
import re
import os
all_files = os.listdir("C:/Users/ndehingia/Desktop/AI in eval/OOS Children Tami/COARs/TXTFiles/")
txt_files = filter(lambda x: x[-4:] == '.txt', all_files)

# %%
n_file=len(all_files)

# %%
n_file
# Out:
# 123
